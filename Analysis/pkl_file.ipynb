# %%
import pickle

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
DATA_PATH = "/content/drive/Data"
infile = open('/content/data1.pkl','rb')
best_model2 = pickle.load(infile)

# %%
print(best_model2.keys())
# Out:
# dict_keys(['xs', 't', 'es'])

# %%
print(len(best_model2['es']))
# Out:
# 25

# %%
print(best_model2['es'])
# Out:
# [[3.66960877 3.66960876 3.66960866 ... 3.66960783 3.66960783 3.66960783]
#  [3.34690818 3.34690818 3.34690826 ... 3.34690731 3.34690731 3.34690731]
#  [5.36067013 5.36067012 5.3606699  ... 5.36066927 5.36066927 5.36066925]
#  ...
#  [5.21089225 5.21089224 5.21089209 ... 5.21089138 5.21089138 5.21089138]
#  [4.15770625 4.15770625 4.15770625 ... 4.15770523 4.15770522 4.15770523]
#  [4.49810756 4.49810756 4.49810757 ... 4.498107   4.49810697 4.49810672]]

# %%
print(len(best_model2['t']))
# Out:
# 1501

# %%
print(len(best_model2['xs']))
# Out:
# 25

# %%
print(len(best_model2['xs'][0]))
# Out:
# 1501
